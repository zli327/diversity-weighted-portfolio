# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import akshare as ak
import tushare as ts
import backtrader as bt
import datetime
from pprint import pprint

# %%
ts.set_token('e5bac81114fbb7a218856eeab26539a5e776b5694fb95153e37b3fcb')
pro = ts.pro_api()

start_date = '20150101'
end_date = '20260601'

trade_cal = pro.trade_cal(exchange='SSE', 
                          start_date=start_date, 
                          end_date=end_date)
trade_cal = trade_cal[trade_cal['is_open'] == 1]
full_calendar = pd.to_datetime(trade_cal['cal_date'], format='%Y%m%d').sort_values()
print(f"Total trade days: {len(full_calendar)}")

index_weight_data = pro.index_weight(index_code = '000300.SH', start_date = start_date, end_date = end_date)
index_weight_data.sort_values(by = 'con_code', inplace = True)
stock_symbols = pd.DataFrame(index_weight_data['con_code'].unique(), columns = ['symbol'])
stock_symbols.to_csv('stock_symbols.csv', encoding = 'utf-8-sig')

for symbol in stock_symbols['symbol']:
    df = pro.daily(ts_code = symbol,  start_date = start_date, end_date = end_date)
    df['trade_date'] = pd.to_datetime(df['trade_date'], format='%Y%m%d')
    df = df.sort_values('trade_date')
    df.rename(columns = {'vol': 'volume'}, inplace = True)
    df = df[['trade_date', 'open', 'high', 'low', 'close', 'volume']]

    db_df = pro.daily_basic(ts_code = symbol, start_date = start_date, end_date = end_date)
    db_df['trade_date'] = pd.to_datetime(db_df['trade_date'], format = '%Y%m%d')
    db_df = db_df.sort_values('trade_date')
    db_df.rename(columns = {'total_mv': 'mkt_cap'}, inplace = True)
    db_df = db_df[['trade_date', 'mkt_cap']]

    df = pd.merge(df, db_df, on = 'trade_date', how = 'left')
    df.set_index('trade_date', inplace = True)

    # 填充
    df = df.reindex(full_calendar)
    df[['open', 'high', 'low', 'close', 'volume']] = df[['open', 'high', 'low', 'close', 'volume']].ffill()
    df[['open', 'high', 'low', 'close', 'volume']] = df[['open', 'high', 'low', 'close', 'volume']].bfill()
    df[['mkt_cap']] = df[['mkt_cap']].fillna(0)

    df.to_csv(f'datas/{symbol}.csv', index = True, encoding = 'utf-8-sig')

# %%
# 在原本的 OHLCV 数据基础上加上市值
class DataWithCap(bt.feeds.PandasData):
    lines = ('mkt_cap', )
    params = (
        ('mkt_cap', 'mkt_cap'),
    )

class DWStrategy(bt.Strategy):
    params = (
        ('invest_ratio', 0.5),
        ('rebalance_days', 21),
        ('p', 0.76)
    )

    # 日志
    def log(self, txt, dt = None):
        dt = dt or self.datas[0].datetime.date(0)  # dt 是一个 date 对象, [0] 代表当前处理的 bar
        print('%s, %s' % (dt.isoformat(), txt))
    
    # 初始化
    def __init__(self):
        self.stock_datas = [d for d in self.datas if d._name != 'benchmark']
        self.names = [d._name for d in self.stock_datas]
        self.log(f'Loaded stocks: {self.names}')

        # 手动记录每日资产和基准收盘价
        self.dates = []
        self.portfolio_values = []
        self.benchmark_values = []

        self.order = None
        self.buyprice = None
        self.buycomm = None

    # 检测 order 状态
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return
        
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY executed, price: %.2f, cost: %.2f, commission: %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))
                
                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            elif order.issell():
                self.log('SELL executed, price: %.2f, cost: %.2f, commission: %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)  # len(self) 是计数器, 代表 next() 方法被调用的次数
        
        elif order.status in[order.Canceled, order.Margin, order.Rejected]:
            self.log('Order canceled/margin/rejected')

        self.order = None
        
    # 计算权重, 由公式 \pi_k = \frac{\mu_k^p}{\sum_{i = 1}^n \mu_i^p} 决定, 其中 \mu_k = \frac{X_k}{\sum_{i = 1}^n X_i} 为市值占比
    def get_target_weights(self):
        total = sum(data.mkt_cap[0] for data in self.stock_datas)
        sum_cap_ratio = 0
        cap_ratio = {}
        weights = {}

        for data in self.stock_datas:
            cap_ratio[data._name] = data.mkt_cap[0] / total if total != 0 else 0
            sum_cap_ratio = sum_cap_ratio + cap_ratio[data._name] ** self.params.p
            
        for name, mu in cap_ratio.items():
            weights[name] = mu ** self.params.p / sum_cap_ratio
        
        return weights
    
    def rebalance(self):
        invest_cash = self.params.invest_ratio * self.broker.getvalue()
        target_weights = self.get_target_weights()

        for data in self.stock_datas:
            target_val = target_weights.get(data._name) * invest_cash
            cur_position = self.getposition(data).size
            target_position = int(target_val / data.close[0])

            if target_position > cur_position:
                self.buy(data = data, size = target_position - cur_position)
            elif target_position < cur_position:
                self.sell(data = data, size = cur_position - target_position)

    def next(self):
        self.dates.append(self.datas[0].datetime.date(0))
        self.portfolio_values.append(self.broker.getvalue())
        self.benchmark_values.append(self.getdatabyname('benchmark').close[0])

        if self.order:
            return
        
        if len(self) % self.params.rebalance_days != 0:
            return
        
        # 仓位调整
        self.rebalance()

# %%
# %matplotlib inline

stock_symbols = pd.read_csv('datas/stock_symbols.csv')['symbol']
stock_symbols = {s: f'datas/{s}.csv' for s in stock_symbols}
fromdate = datetime.datetime(2020, 1, 1)
todate = datetime.datetime(2025, 12, 31)

if __name__ == '__main__':
    cerebro = bt.Cerebro()

    cerebro.addstrategy(DWStrategy)

    # 导入股票数据
    for symbol, stock in stock_symbols.items():
        data_df = pd.read_csv(stock, index_col = 0, parse_dates = True)

        # 表格数据类型用手动设置的继承 bt.feeds.PandasData 的带市值的数据类型 DataWithCap 类
        data = DataWithCap(
            dataname = data_df,
            fromdate = fromdate,
            todate = todate
        )
        cerebro.adddata(data, name = symbol)

    # 导入基准
    benchmark_df = pd.read_csv('datas/hs300.csv', index_col = 0, parse_dates = True)
    benchmark = bt.feeds.PandasData(
        dataname = benchmark_df,
        fromdate = fromdate,
        todate = todate
    )
    cerebro.adddata(benchmark, name = 'benchmark')

    cerebro.addobserver(bt.observers.Benchmark, data = benchmark)
    
    # 加入分析指标
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name = 'sharp_ratio')
    cerebro.addanalyzer(bt.analyzers.AnnualReturn, _name = 'annual_return')
    cerebro.addanalyzer(bt.analyzers.DrawDown, _name = 'draw_down')

    # 分析总收益
    cerebro.addanalyzer(
        bt.analyzers.TimeReturn,
        timeframe = bt.TimeFrame.NoTimeFrame,
        _name = 'total_return'
    )
    cerebro.addanalyzer(
        bt.analyzers.TimeReturn,
        timeframe = bt.TimeFrame.NoTimeFrame,
        data = benchmark,
        _name = 'benchmark_return'
    )

    # 设置 broker 的初始资金以及佣金
    cerebro.broker.setcash(100000.0)
    cerebro.broker.setcommission(commission = 0.001)

    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # 执行策略并获取策略实例
    results = cerebro.run()
    strategy = results[0]

    # 计算每日收益率
    dates = strategy.dates
    portfolio_values = strategy.portfolio_values
    benchmark_values = strategy.benchmark_values

    portfolio_returns = pd.DataFrame(np.array(portfolio_values) / portfolio_values[0] - 1, index = dates)
    benchmark_returns = pd.DataFrame(np.array(benchmark_values) / benchmark_values[0] - 1, index = dates)

    portfolio_returns.index = pd.to_datetime(portfolio_returns.index)
    benchmark_returns.index = pd.to_datetime(benchmark_returns.index)

    # 计算总收益率
    total_return = strategy.analyzers.getbyname('total_return').get_analysis()
    total_return = list(total_return.values())[-1]

    benchmark_return = strategy.analyzers.getbyname('benchmark_return').get_analysis()
    benchmark_return = list(benchmark_return.values())[-1]

    # 导出指标
    sharp_ratio = strategy.analyzers.sharp_ratio.get_analysis()
    annual_return = strategy.analyzers.annual_return.get_analysis()
    draw_down = strategy.analyzers.draw_down.get_analysis()

    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    print('Total Return: %.4f' % total_return)
    print('Benchmark Return: %.4f' % benchmark_return)
    pprint(annual_return)
    pprint(sharp_ratio)
    pprint(annual_return)
    pprint(draw_down)

    # 绘图
    plt.figure(figsize = (24, 8))
    plt.plot(portfolio_returns, label = 'Portfolio Return')
    plt.plot(benchmark_returns, label = 'Benchmark', linestyle = '--')
    plt.xlim(fromdate, todate)
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    plt.gca().xaxis.set_major_locator(mdates.YearLocator())
    plt.xticks(rotation=45)
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# Starting Portfolio Value: 100000.00
# 2025-12-31, Loaded stocks: ['000001.SZ', '000002.SZ', '000063.SZ', '000100.SZ', '000157.SZ', '000166.SZ', '000301.SZ', '000333.SZ', '000338.SZ', '000408.SZ', '000425.SZ', '000538.SZ', '000568.SZ', '000596.SZ', '000617.SZ', '000625.SZ', '000630.SZ', '000651.SZ', '000661.SZ', '000708.SZ', '000725.SZ', '000768.SZ', '000776.SZ', '000786.SZ', '000792.SZ', '000800.SZ', '000807.SZ', '000858.SZ', '000876.SZ', '000895.SZ', '000938.SZ', '000963.SZ', '000975.SZ', '000977.SZ', '000983.SZ', '000999.SZ', '001289.SZ', '001391.SZ', '001965.SZ', '001979.SZ', '002001.SZ', '002027.SZ', '002028.SZ', '002049.SZ', '002050.SZ', '002074.SZ', '002129.SZ', '002142.SZ', '002179.SZ', '002180.SZ', '002230.SZ', '002236.SZ', '002241.SZ', '002252.SZ', '002304.SZ', '002311.SZ', '002352.SZ', '002371.SZ', '002384.SZ', '002415.SZ', '002422.SZ', '002459.SZ', '002460.SZ', '002463.SZ', '002466.SZ', '002475.SZ', '002493.SZ', '002594.SZ', '002600.SZ', '002601.SZ', '002625.SZ', '002648.SZ', '002709.SZ', '002714.SZ', '002736.SZ', '002916.SZ', '002920.SZ', '002938.SZ', '003816.SZ', '300014.SZ', '300015.SZ', '300033.SZ', '300059.SZ', '300122.SZ', '300124.SZ', '300251.SZ', '300274.SZ', '300308.SZ', '300316.SZ', '300347.SZ', '300394.SZ', '300408.SZ', '300413.SZ', '300418.SZ', '300433.SZ', '300442.SZ', '300476.SZ', '300498.SZ', '300502.SZ', '300628.SZ', '300661.SZ', '300750.SZ', '300759.SZ', '300760.SZ', '300782.SZ', '300803.SZ', '300832.SZ', '300866.SZ', '300896.SZ', '300979.SZ', '300999.SZ', '301236.SZ', '301269.SZ', '302132.SZ', '600000.SH', '600009.SH', '600010.SH', '600011.SH', '600015.SH', '600016.SH', '600018.SH', '600019.SH', '600023.SH', '600025.SH', '600026.SH', '600027.SH', '600028.SH', '600029.SH', '600030.SH', '600031.SH', '600036.SH', '600039.SH', '600048.SH', '600050.SH', '600061.SH', '600066.SH', '600085.SH', '600089.SH', '600104.SH', '600111.SH', '600115.SH', '600150.SH', '600160.SH', '600161.SH', '600176.SH', '600183.SH', '600188.SH', '600196.SH', '600219.SH', '600233.SH', '600276.SH', '600309.SH', '600332.SH', '600346.SH', '600362.SH', '600372.SH', '600377.SH', '600406.SH', '600415.SH', '600426.SH', '600436.SH', '600438.SH', '600460.SH', '600482.SH', '600489.SH', '600515.SH', '600519.SH', '600522.SH', '600547.SH', '600570.SH', '600584.SH', '600585.SH', '600588.SH', '600600.SH', '600660.SH', '600674.SH', '600690.SH', '600741.SH', '600760.SH', '600795.SH', '600803.SH', '600809.SH', '600845.SH', '600875.SH', '600886.SH', '600887.SH', '600893.SH', '600900.SH', '600905.SH', '600918.SH', '600919.SH', '600926.SH', '600930.SH', '600938.SH', '600941.SH', '600958.SH', '600989.SH', '600999.SH', '601006.SH', '601009.SH', '601012.SH', '601018.SH', '601021.SH', '601058.SH', '601059.SH', '601066.SH', '601077.SH', '601088.SH', '601100.SH', '601111.SH', '601117.SH', '601127.SH', '601136.SH', '601138.SH', '601166.SH', '601169.SH', '601186.SH', '601211.SH', '601225.SH', '601229.SH', '601236.SH', '601238.SH', '601288.SH', '601298.SH', '601318.SH', '601319.SH', '601328.SH', '601336.SH', '601360.SH', '601377.SH', '601390.SH', '601398.SH', '601456.SH', '601600.SH', '601601.SH', '601607.SH', '601618.SH', '601628.SH', '601633.SH', '601658.SH', '601668.SH', '601669.SH', '601688.SH', '601689.SH', '601698.SH', '601699.SH', '601728.SH', '601766.SH', '601788.SH', '601799.SH', '601800.SH', '601808.SH', '601816.SH', '601818.SH', '601825.SH', '601838.SH', '601857.SH', '601865.SH', '601868.SH', '601872.SH', '601877.SH', '601878.SH', '601881.SH', '601888.SH', '601898.SH', '601899.SH', '601901.SH', '601916.SH', '601919.SH', '601939.SH', '601985.SH', '601988.SH', '601989.SH', '601995.SH', '601998.SH', '603019.SH', '603195.SH', '603259.SH', '603260.SH', '603288.SH', '603296.SH', '603369.SH', '603392.SH', '603501.SH', '603799.SH', '603806.SH', '603833.SH', '603893.SH', '603986.SH', '603993.SH', '605117.SH', '605499.SH', '688008.SH', '688009.SH', '688012.SH', '688036.SH', '688041.SH', '688047.SH', '688082.SH', '688111.SH', '688126.SH', '688169.SH', '688187.SH', '688223.SH', '688256.SH', '688271 ...
# 2020-02-10, BUY executed, price: 14.51, cost: 362.75, commission: 0.36
# 2020-02-10, BUY executed, price: 27.25, cost: 381.50, commission: 0.38
# 2020-02-10, BUY executed, price: 38.55, cost: 231.30, commission: 0.23
# 2020-02-10, BUY executed, price: 5.55, cost: 133.20, commission: 0.13
# 2020-02-10, BUY executed, price: 5.96, cost: 89.40, commission: 0.09
# 2020-02-10, BUY executed, price: 4.42, cost: 176.80, commission: 0.18
# 2020-02-10, BUY executed, price: 4.90, cost: 44.10, commission: 0.04
# 2020-02-10, BUY executed, price: 52.30, cost: 418.40, commission: 0.42
# 2020-02-10, BUY executed, price: 13.28, cost: 172.64, commission: 0.17
# 2020-02-10, BUY executed, price: 6.19, cost: 30.95, commission: 0.03
# 2020-02-10, BUY executed, price: 4.72, cost: 75.52, commission: 0.08
# 2020-02-10, BUY executed, price: 84.14, cost: 168.28, commission: 0.17
# 2020-02-10, BUY executed, price: 74.00, cost: 148.00, commission: 0.15
# 2020-02-10, BUY executed, price: 10.20, cost: 153.00, commission: 0.15
# 2020-02-10, BUY executed, price: 8.99, cost: 80.91, commission: 0.08
# 2020-02-10, BUY executed, price: 1.99, cost: 49.75, commission: 0.05
# 2020-02-10, BUY executed, price: 62.00, cost: 434.00, commission: 0.43
# 2020-02-10, BUY executed, price: 22.04, cost: 110.20, commission: 0.11
# 2020-02-10, BUY executed, price: 4.60, cost: 234.60, commission: 0.23
# 2020-02-10, BUY executed, price: 15.53, cost: 77.65, commission: 0.08
# 2020-02-10, BUY executed, price: 13.94, cost: 167.28, commission: 0.17
# 2020-02-10, BUY executed, price: 23.90, cost: 71.70, commission: 0.07
# 2020-02-10, BUY executed, price: 8.05, cost: 48.30, commission: 0.05
# 2020-02-10, BUY executed, price: 8.50, cost: 34.00, commission: 0.03
# 2020-02-10, BUY executed, price: 4.25, cost: 34.00, commission: 0.03
# 2020-02-10, BUY executed, price: 119.50, cost: 478.00, commission: 0.48
# 2020-02-10, BUY executed, price: 19.15, cost: 134.05, commission: 0.13
# 2020-02-10, BUY executed, price: 32.64, cost: 163.20, commission: 0.16
# 2020-02-10, BUY executed, price: 36.70, cost: 110.10, commission: 0.11
# 2020-02-10, BUY executed, price: 21.17, cost: 63.51, commission: 0.06
# 2020-02-10, BUY executed, price: 11.88, cost: 47.52, commission: 0.05
# 2020-02-10, BUY executed, price: 44.78, cost: 89.56, commission: 0.09
# 2020-02-10, BUY executed, price: 5.05, cost: 40.40, commission: 0.04
# 2020-02-10, BUY executed, price: 35.19, cost: 70.38, commission: 0.07
# 2020-02-10, BUY executed, price: 7.41, cost: 88.92, commission: 0.09
# 2020-02-10, BUY executed, price: 16.42, cost: 197.04, commission: 0.20
# 2020-02-10, BUY executed, price: 23.37, cost: 93.48, commission: 0.09
# 2020-02-10, BUY executed, price: 5.28, cost: 132.00, commission: 0.13
# 2020-02-10, BUY executed, price: 13.08, cost: 26.16, commission: 0.03
# 2020-02-10, BUY executed, price: 54.80, cost: 54.80, commission: 0.05
# 2020-02-10, BUY executed, price: 21.22, cost: 106.10, commission: 0.11
# 2020-02-10, BUY executed, price: 25.50, cost: 51.00, commission: 0.05
# 2020-02-10, BUY executed, price: 16.07, cost: 80.35, commission: 0.08
# 2020-02-10, BUY executed, price: 25.27, cost: 202.16, commission: 0.20
# 2020-02-10, BUY executed, price: 36.29, cost: 72.58, commission: 0.07
# 2020-02-10, BUY executed, price: 37.07, cost: 74.14, commission: 0.07
# 2020-02-10, BUY executed, price: 39.11, cost: 117.33, commission: 0.12
# 2020-02-10, BUY executed, price: 20.26, cost: 101.30, commission: 0.10
# 2020-02-10, BUY executed, price: 20.20, cost: 101.00, commission: 0.10
# 2020-02-10, BUY executed, price: 9.50, cost: 85.50, commission: 0.09
# 2020-02-10, BUY executed, price: 102.00, cost: 204.00, commission: 0.20
# 2020-02-10, BUY executed, price: 32.50, cost: 97.50, commission: 0.10
# 2020-02-10, BUY executed, price: 44.85, cost: 269.10, commission: 0.27
# 2020-02-10, BUY executed, price: 26.40, cost: 79.20, commission: 0.08
# 2020-02-10, BUY executed, price: 35.02, cost: 385.22, commission: 0.39
# 2020-02-10, BUY executed, price: 26.00, cost: 78.00, commission: 0.08
# 2020-02-10, BUY executed, price: 15.56, cost: 46.68, commission: 0.05
# 2020-02-10, BUY executed, price: 46.60, cost: 93.20, commission: 0.09
# 2020-02-10, BUY executed, price: 22.28, cost: 66.84, commission: 0.07
# 2020-02-10, BUY executed, price: 27.32, cost: 81.96, commission: 0.08
# 2020-02-10, BUY executed, price: 41.52, cost: 290.64, commission: 0.29
# 2020-02-10, BUY executed, price: 10.47, cost: 115.17, commission: 0.12
# 2020-02-10, BUY executed, price: 59.20, cost: 236.80, commission: 0.24
# 2020-02-10, BUY executed, price: 11.00, cost: 132.00, commission: 0.13
# 2020-02-10, BUY executed, price: 15.32, cost: 61.28, commission: 0.06
# 2020-02-10, BUY executed, price: 7.74, cost: 38.70, commission: 0.04
# 2020-02-10, BUY executed, price: 17.70, cost: 35.40, commission: 0.04
# 2020-02-10, BUY executed, price: 29.53, cost: 29.53, commission: 0.03
# 2020-02-10, BUY executed, price: 92.48, cost: 277.44, commission: 0.28
# 2020-02-10, BUY executed, price: 11.49, cost: 149.37, commission: 0.15
# 2020-02-10, BUY executed, price: 33.90, cost: 33.90, commission: 0.03
# 2020-02-10, BUY executed, price: 42.22, cost: 126.66, commission: 0.13
# 2020-02-10, BUY executed, price: 3.22, cost: 238.28, commission: 0.24
# 2020-02-10, BUY executed, price: 61.50, cost: 61.50, commission: 0.06
# 2020-02-10, BUY executed, price: 40.25, cost: 161.00, commission: 0.16
# 2020-02-10, BUY executed, price: 103.48, cost: 103.48, commission: 0.10
# 2020-02-10, BUY executed, price: 14.56, cost: 160.16, commission: 0.16
# 2020-02-10, BUY executed, price: 64.30, cost: 128.60, commission: 0.13
# 2020-02-10, BUY executed, price: 28.39, cost: 85.17, commission: 0.09
# 2020-02-10, BUY executed, price: 10.00, cost: 60.00, commission: 0.06
# 2020-02-10, BUY executed, price: 10.59, cost: 31.77, commission: 0.03
# 2020-02-10, BUY executed, price: 62.92, cost: 62.92, commission: 0.06
# 2020-02-10, BUY executed, price: 20.40, cost: 40.80, commission: 0.04
# 2020-02-10, BUY executed, price: 80.01, cost: 80.01, commission: 0.08
# 2020-02-10, BUY executed, price: 21.60, cost: 64.80, commission: 0.06
# 2020-02-10, BUY executed, price: 50.10, cost: 150.30, commission: 0.15
# 2020-02-10, BUY executed, price: 24.95, cost: 49.90, commission: 0.05
# 2020-02-10, BUY executed, price: 18.73, cost: 131.11, commission: 0.13
# 2020-02-10, BUY executed, price: 20.16, cost: 40.32, commission: 0.04
# 2020-02-10, BUY executed, price: 30.61, cost: 214.27, commission: 0.21
# 2020-02-10, BUY executed, price: 99.00, cost: 99.00, commission: 0.10
# 2020-02-10, BUY executed, price: 161.00, cost: 322.00, commission: 0.32
# 2020-02-10, BUY executed, price: 55.00, cost: 55.00, commission: 0.06
# 2020-02-10, BUY executed, price: 217.00, cost: 217.00, commission: 0.22
# 2020-02-10, BUY executed, price: 39.10, cost: 39.10, commission: 0.04
# 2020-02-10, BUY executed, price: 10.56, cost: 10.56, commission: 0.01
# 2020-02-10, BUY executed, price: 10.76, cost: 398.12, commission: 0.40
# 2020-02-10, BUY executed, price: 71.00, cost: 142.00, commission: 0.14
# 2020-02-10, BUY executed, price: 1.16, cost: 102.08, commission: 0.10
# 2020-02-10, BUY executed, price: 4.91, cost: 132.57, commission: 0.13
# 2020-02-10, BUY executed, price: 7.09, cost: 177.25, commission: 0.18
# 2020-02-10, BUY executed, price: 5.85, cost: 339.30, commission: 0.34
# 2020-02-10, BUY executed, price: 4.66, cost: 172.42, commission: 0.17
# 2020-02-10, BUY executed, price: 5.18, cost: 181.30, commission: 0.18
# 2020-02-10, BUY executed, price: 3.51, cost: 94.77, commission: 0.09
# 2020-02-10, BUY executed, price: 3.92, cost: 125.44, commission: 0.13
# 2020-02-10, BUY executed, price: 5.74, cost: 51.66, commission: 0.05
# 2020-02-10, BUY executed, price: 3.28, cost: 68.88, commission: 0.07
# 2020-02-10, BUY executed, price: 4.74, cost: 625.68, commission: 0.63
# 2020-02-10, BUY executed, price: 5.82, cost: 128.04, commission: 0.13
# 2020-02-10, BUY executed, price: 22.20, cost: 333.00, commission: 0.33
# 2020-02-10, BUY executed, price: 15.66, cost: 203.58, commission: 0.20
# 2020-02-10, BUY executed, price: 35.13, cost: 843.12, commission: 0.84
# 2020-02-10, BUY executed, price: 3.32, cost: 33.20, commission: 0.03
# 2020-02-10, BUY executed, price: 14.19, cost: 241.23, commission: 0.24
# 2020-02-10, BUY executed, price: 5.32, cost: 239.40, commission: 0.24
# 2020-02-10, BUY executed, price: 13.00, cost: 104.00, commission: 0.10
# 2020-02-10, BUY executed, price: 13.95, cost: 55.80, commission: 0.06
# 2020-02-10, BUY executed, price: 29.00, cost: 58.00, commission: 0.06
# 2020-02-10, BUY executed, price: 6.00, cost: 48.00, commission: 0.05
# 2020-02-10, BUY executed, price: 21.00, cost: 315.00, commission: 0.32
# 2020-02-10, BUY executed, price: 9.37, cost: 65.59, commission: 0.07
# 2020-02-10, BUY executed, price: 4.64, cost: 134.56, commission: 0.13
# 2020-02-10, BUY executed, price: 18.91, cost: 56.73, commission: 0.06
# 2020-02-10, BUY executed, price: 6.81, cost: 40.86, commission: 0.04
# 2020-02-10, BUY executed, price: 35.60, cost: 71.20, commission: 0.07
# 2020-02-10, BUY executed, price: 9.65, cost: 67.55, commission: 0.07
# 2020-02-10, BUY executed, price: 22.94, cost: 91.76, commission: 0.09
# 2020-02-10, BUY executed, price: 8.89, cost: 80.01, commission: 0.08
# 2020-02-10, BUY executed, price: 27.64, cost: 110.56, commission: 0.11
# 2020-02-10, BUY executed, price: 2.08, cost: 56.16, commission: 0.06
# 2020-02-10, BUY executed, price: 15.31, cost: 76.55, commission: 0.08
# 2020-02-10, BUY executed, price: 88.70, cost: 443.50, commission: 0.44
# 2020-02-10, BUY executed, price: 48.81, cost: 195.24, commission: 0.20
# 2020-02-10, BUY executed, price: 38.00, cost: 114.00, commission: 0.11
# 2020-02-10, BUY executed, price: 15.53, cost: 170.83, commission: 0.17
# 2020-02-10, BUY executed, price: 13.87, cost: 83.22, commission: 0.08
# 2020-02-10, BUY executed, price: 13.52, cost: 54.08, commission: 0.05
# 2020-02-10, BUY executed, price: 10.82, cost: 97.38, commission: 0.10
# 2020-02-10, BUY executed, price: 17.53, cost: 140.24, commission: 0.14
# 2020-02-10, BUY executed, price: 3.40, cost: 44.20, commission: 0.04
# 2020-02-10, BUY executed, price: 18.11, cost: 54.33, commission: 0.05
# 2020-02-10, BUY executed, price: 131.30, cost: 131.30, commission: 0.13
# 2020-02-10, BUY executed, price: 14.46, cost: 101.22, commission: 0.10
# 2020-02-10, BUY executed, price: 15.22, cost: 45.66, commission: 0.05
# 2020-02-10, BUY executed, price: 17.11, cost: 51.33, commission: 0.05
# 2020-02-10, BUY executed, price: 7.82, cost: 54.74, commission: 0.05
# 2020-02-10, BUY executed, price: 4.36, cost: 39.24, commission: 0.04
# 2020-02-10, BUY executed, price: 1062.00, cost: 1062.00, commission: 1.06
# 2020-02-10, BUY executed, price: 7.49, cost: 52.43, commission: 0.05
# 2020-02-10, BUY executed, price: 32.58, cost: 162.90, commission: 0.16
# 2020-02-10, BUY executed, price: 91.30, cost: 91.30, commission: 0.09
# 2020-02-10, BUY executed, price: 26.09, cost: 78.27, commission: 0.08
# 2020-02-10, BUY executed, price: 47.80, cost: 334.60, commission: 0.33
# 2020-02-10, BUY executed, price: 37.96, cost: 151.84, commission: 0.15
# 2020-02-10, BUY executed, price: 45.30, cost: 90.60, commission: 0.09
# 2020-02-10, BUY executed, price: 23.75, cost: 95.00, commission: 0.10
# 2020-02-10, BUY executed, price: 8.77, cost: 78.93, commission: 0.08
# 2020-02-10, BUY executed, price: 17.65, cost: 176.50, commission: 0.18
# 2020-02-10, BUY executed, price: 25.50, cost: 127.50, commission: 0.13
# 2020-02-10, BUY executed, price: 27.30, cost: 54.60, commission: 0.05
# 2020-02-10, BUY executed, price: 2.09, cost: 83.60, commission: 0.08
# 2020-02-10, BUY executed, price: 9.80, cost: 29.40, commission: 0.03
# 2020-02-10, BUY executed, price: 84.90, cost: 84.90, commission: 0.08
# 2020-02-10, BUY executed, price: 50.86, cost: 101.72, commission: 0.10
# 2020-02-10, BUY executed, price: 8.00, cost: 56.00, commission: 0.06
# 2020-02-10, BUY executed, price: 7.92, cost: 102.96, commission: 0.10
# 2020-02-10, BUY executed, price: 30.35, cost: 242.80, commission: 0.24
# 2020-02-10, BUY executed, price: 20.73, cost: 82.92, commission: 0.08
# 2020-02-10, BUY executed, price: 17.68, cost: 459.68, commission: 0.46
# 2020-02-10, BUY executed, price: 6.52, cost: 130.40, commission: 0.13
# 2020-02-10, BUY executed, price: 8.58, cost: 85.80, commission: 0.09
# 2020-02-10, BUY executed, price: 9.34, cost: 112.08, commission: 0.11
# 2020-02-10, BUY executed, price: 8.11, cost: 105.43, commission: 0.11
# 2020-02-10, BUY executed, price: 17.35, cost: 173.50, commission: 0.17
# 2020-02-10, BUY executed, price: 7.30, cost: 175.20, commission: 0.18
# 2020-02-10, BUY executed, price: 7.83, cost: 117.45, commission: 0.12
# 2020-02-10, BUY executed, price: 32.55, cost: 162.75, commission: 0.16
# 2020-02-10, BUY executed, price: 3.22, cost: 83.72, commission: 0.08
# 2020-02-10, BUY executed, price: 37.33, cost: 37.33, commission: 0.04
# 2020-02-10, BUY executed, price: 4.28, cost: 29.96, commission: 0.03
# 2020-02-10, BUY executed, price: 32.20, cost: 322.00, commission: 0.32
# 2020-02-10, BUY executed, price: 5.73, cost: 114.60, commission: 0.11
# 2020-02-10, BUY executed, price: 16.07, cost: 401.75, commission: 0.40
# 2020-02-10, BUY executed, price: 47.03, cost: 47.03, commission: 0.05
# 2020-02-10, BUY executed, price: 7.81, cost: 179.63, commission: 0.18
# 2020-02-10, BUY executed, price: 7.40, cost: 74.00, commission: 0.07
# 2020-02-10, BUY executed, price: 9.25, cost: 18.50, commission: 0.02
# 2020-02-10, BUY executed, price: 18.90, cost: 434.70, commission: 0.43
# 2020-02-10, BUY executed, price: 17.46, cost: 436.50, commission: 0.44
# 2020-02-10, BUY executed, price: 5.22, cost: 177.48, commission: 0.18
# 2020-02-10, BUY executed, price: 8.75, cost: 183.75, commission: 0.18
# 2020-02-10, BUY executed, price: 16.60, cost: 215.80, commission: 0.22
# 2020-02-10, BUY executed, price: 7.82, cost: 132.94, commission: 0.13
# 2020-02-10, BUY executed, price: 8.59, cost: 188.98, commission: 0.19
# 2020-02-10, BUY executed, price: 16.44, cost: 98.64, commission: 0.10
# 2020-02-10, BUY executed, price: 10.09, cost: 161.44, commission: 0.16
# 2020-02-10, BUY executed, price: 3.38, cost: 1088.36, commission: 1.09
# 2020-02-10, BUY executed, price: 5.82, cost: 75.66, commission: 0.08
# 2020-02-10, BUY executed, price: 80.35, cost: 1205.25, commission: 1.21
# 2020-02-10, BUY executed, price: 6.80, cost: 380.80, commission: 0.38
# 2020-02-10, BUY executed, price: 5.23, cost: 465.47, commission: 0.47
# 2020-02-10, BUY executed, price: 45.79, cost: 183.16, commission: 0.18
# 2020-02-10, BUY executed, price: 24.20, cost: 242.00, commission: 0.24
# 2020-02-10, BUY executed, price: 6.39, cost: 83.07, commission: 0.08
# 2020-02-10, BUY executed, price: 5.13, cost: 194.94, commission: 0.19
# 2020-02-10, BUY executed, price: 5.41, cost: 1574.31, commission: 1.57
# 2020-02-10, BUY executed, price: 3.02, cost: 99.66, commission: 0.10
# 2020-02-10, BUY executed, price: 33.18, cost: 364.98, commission: 0.36
# 2020-02-10, BUY executed, price: 20.50, cost: 102.50, commission: 0.10
# 2020-02-10, BUY executed, price: 2.44, cost: 97.60, commission: 0.10
# 2020-02-10, BUY executed, price: 29.80, cost: 834.40, commission: 0.83
# 2020-02-10, BUY executed, price: 7.61, cost: 121.76, commission: 0.12
# 2020-02-10, BUY executed, price: 5.47, cost: 541.53, commission: 0.54
# 2020-02-10, BUY executed, price: 5.23, cost: 298.11, commission: 0.30
# 2020-02-10, BUY executed, price: 3.82, cost: 106.96, commission: 0.11
# 2020-02-10, BUY executed, price: 17.78, cost: 231.14, commission: 0.23
# 2020-02-10, BUY executed, price: 25.37, cost: 50.74, commission: 0.05
# 2020-02-10, BUY executed, price: 19.00, cost: 133.00, commission: 0.13
# 2020-02-10, BUY executed, price: 6.15, cost: 43.05, commission: 0.04
# 2020-02-10, BUY executed, price: 6.15, cost: 252.15, commission: 0.25
# 2020-02-10, BUY executed, price: 11.33, cost: 90.64, commission: 0.09
# 2020-02-10, BUY executed, price: 7.55, cost: 188.75, commission: 0.19
# 2020-02-10, BUY executed, price: 16.36, cost: 130.88, commission: 0.13
# 2020-02-10, BUY executed, price: 7.58, cost: 447.22, commission: 0.45
# 2020-02-10, BUY executed, price: 3.77, cost: 278.98, commission: 0.28
# 2020-02-10, BUY executed, price: 8.20, cost: 65.60, commission: 0.07
# 2020-02-10, BUY executed, price: 5.24, cost: 927.48, commission: 0.93
# 2020-02-10, BUY executed, price: 12.69, cost: 50.76, commission: 0.05
# 2020-02-10, BUY executed, price: 5.36, cost: 75.04, commission: 0.08
# 2020-02-10, BUY executed, price: 25.80, cost: 103.20, commission: 0.10
# 2020-02-10, BUY executed, price: 10.14, cost: 70.98, commission: 0.07
# 2020-02-10, BUY executed, price: 10.10, cost: 161.60, commission: 0.16
# 2020-02-10, BUY executed, price: 79.50, cost: 159.00, commission: 0.16
# 2020-02-10, BUY executed, price: 4.27, cost: 106.75, commission: 0.11
# 2020-02-10, BUY executed, price: 4.06, cost: 166.46, commission: 0.17
# 2020-02-10, BUY executed, price: 7.58, cost: 113.70, commission: 0.11
# 2020-02-10, BUY executed, price: 4.21, cost: 151.56, commission: 0.15
# 2020-02-10, BUY executed, price: 4.14, cost: 99.36, commission: 0.10
# 2020-02-10, BUY executed, price: 6.60, cost: 1399.20, commission: 1.40
# 2020-02-10, BUY executed, price: 4.57, cost: 127.96, commission: 0.13
# 2020-02-10, BUY executed, price: 3.49, cost: 977.20, commission: 0.98
# 2020-02-10, BUY executed, price: 4.37, cost: 166.06, commission: 0.17
# 2020-02-10, BUY executed, price: 5.54, cost: 354.56, commission: 0.35
# 2020-02-10, BUY executed, price: 47.97, cost: 47.97, commission: 0.05
# 2020-02-10, BUY executed, price: 103.59, cost: 103.59, commission: 0.10
# 2020-02-10, BUY executed, price: 101.58, cost: 203.16, commission: 0.20
# 2020-02-10, BUY executed, price: 25.76, cost: 51.52, commission: 0.05
# 2020-02-10, BUY executed, price: 105.60, cost: 316.80, commission: 0.32
# 2020-02-10, BUY executed, price: 28.20, cost: 56.40, commission: 0.06
# 2020-02-10, BUY executed, price: 195.21, cost: 195.21, commission: 0.20
# 2020-02-10, BUY executed, price: 41.96, cost: 83.92, commission: 0.08
# 2020-02-10, BUY executed, price: 47.64, cost: 47.64, commission: 0.05
# 2020-02-10, BUY executed, price: 15.33, cost: 15.33, commission: 0.02
# 2020-02-10, BUY executed, price: 3.83, cost: 141.71, commission: 0.14
# 2020-02-10, BUY executed, price: 115.80, cost: 115.80, commission: 0.12
# 2020-02-10, BUY executed, price: 6.22, cost: 118.18, commission: 0.12
# 2020-02-10, BUY executed, price: 70.94, cost: 70.94, commission: 0.07
# 2020-03-10, SELL executed, price: 30.60, cost: 27.25, commission: 0.03
# 2020-03-10, SELL executed, price: 5.92, cost: 5.55, commission: 0.01
# 2020-03-10, SELL executed, price: 4.76, cost: 4.42, commission: 0.00
# 2020-03-10, SELL executed, price: 13.97, cost: 13.28, commission: 0.01
# 2020-03-10, SELL executed, price: 5.31, cost: 4.72, commission: 0.01
# 2020-03-10, SELL executed, price: 4.81, cost: 4.60, commission: 0.00
# 2020-03-10, SELL executed, price: 28.88, cost: 19.15, commission: 0.03
# 2020-03-10, SELL executed, price: 18.40, cost: 16.42, commission: 0.02
# 2020-03-10, BUY executed, price: 8.70, cost: 8.70, commission: 0.01
# 2020-03-10, SELL executed, price: 31.22, cost: 27.32, commission: 0.03
# 2020-03-10, SELL executed, price: 134.12, cost: 92.48, commission: 0.13
# 2020-03-10, SELL executed, price: 122.00, cost: 103.48, commission: 0.12
# 2020-03-10, SELL executed, price: 18.30, cost: 14.56, commission: 0.02
# 2020-03-10, SELL executed, price: 21.90, cost: 20.16, commission: 0.02
# 2020-03-10, SELL executed, price: 54.96, cost: 39.10, commission: 0.05
# 2020-03-10, SELL executed, price: 10.71, cost: 10.76, commission: 0.01
# 2020-03-10, SELL executed, price: 1.18, cost: 1.16, commission: 0.00
# 2020-03-10, SELL executed, price: 3.46, cost: 3.51, commission: 0.00
# 2020-03-10, SELL executed, price: 4.85, cost: 9.48, commission: 0.01
# 2020-03-10, SELL executed, price: 6.00, cost: 5.82, commission: 0.01
# 2020-03-10, SELL executed, price: 17.25, cost: 15.66, commission: 0.02
# 2020-03-10, SELL executed, price: 3.61, cost: 3.32, commission: 0.00
# 2020-03-10, SELL executed, price: 16.29, cost: 14.19, commission: 0.02
# 2020-03-10, SELL executed, price: 5.58, cost: 5.32, commission: 0.01
# 2020-03-10, SELL executed, price: 4.73, cost: 4.64, commission: 0.00
# 2020-03-10, SELL executed, price: 21.01, cost: 17.53, commission: 0.02
# 2020-03-10, SELL executed, price: 9.08, cost: 7.49, commission: 0.01
# 2020-03-10, SELL executed, price: 55.70, cost: 47.80, commission: 0.06
# 2020-03-10, SELL executed, price: 9.27, cost: 8.00, commission: 0.01
# 2020-03-10, SELL executed, price: 9.90, cost: 8.11, commission: 0.01
# 2020-03-10, BUY executed, price: 28.10, cost: 28.10, commission: 0.03
# 2020-03-10, SELL executed, price: 35.90, cost: 32.20, commission: 0.04
# 2020-03-10, SELL executed, price: 16.19, cost: 16.07, commission: 0.02
# 2020-03-10, BUY executed, price: 15.98, cost: 15.98, commission: 0.02
# 2020-03-10, SELL executed, price: 10.15, cost: 8.75, commission: 0.01
# 2020-03-10, SELL executed, price: 3.41, cost: 10.14, commission: 0.01
# 2020-03-10, BUY executed, price: 78.14, cost: 78.14, commission: 0.08
# 2020-03-10, SELL executed, price: 5.24, cost: 5.23, commission: 0.01
# 2020-03-10, SELL executed, price: 5.54, cost: 5.13, commission: 0.01
# 2020-03-10, SELL executed, price: 3.07, cost: 3.02, commission: 0.00
# 2020-03-10, SELL executed, price: 2.70, cost: 2.44, commission: 0.00
# 2020-03-10, SELL executed, price: 8.49, cost: 7.61, commission: 0.01
# 2020-03-10, SELL executed, price: 5.45, cost: 5.23, commission: 0.01
# 2020-03-10, SELL executed, price: 6.41, cost: 6.15, commission: 0.01
# 2020-03-10, SELL executed, price: 9.15, cost: 7.55, commission: 0.01
# 2020-03-10, BUY executed, price: 6.80, cost: 6.80, commission: 0.01
# 2020-03-10, SELL executed, price: 3.80, cost: 3.77, commission: 0.00
# 2020-03-10, SELL executed, price: 6.33, cost: 5.36, commission: 0.01
# 2020-03-10, SELL executed, price: 11.91, cost: 10.14, commission: 0.01
# 2020-03-10, SELL executed, price: 4.25, cost: 4.14, commission: 0.00
# 2020-03-10, SELL executed, price: 4.65, cost: 4.57, commission: 0.00
# 2020-03-10, SELL executed, price: 3.56, cost: 10.47, commission: 0.01
# 2020-03-10, SELL executed, price: 4.38, cost: 4.37, commission: 0.00
# 2020-03-10, SELL executed, price: 76.03, cost: 15.33, commission: 0.08
# 2020-03-10, SELL executed, price: 4.07, cost: 3.83, commission: 0.00
# 2020-03-10, SELL executed, price: 6.87, cost: 6.22, commission: 0.01
# 2020-03-10, BUY executed, price: 42.60, cost: 85.20, commission: 0.09
# 2020-04-09, BUY executed, price: 12.88, cost: 12.88, commission: 0.01
# 2020-04-09, BUY executed, price: 27.10, cost: 27.10, commission: 0.03
# 2020-04-09, BUY executed, price: 4.65, cost: 9.30, commission: 0.01
# 2020-04-09, BUY executed, price: 4.46, cost: 4.46, commission: 0.00
# 2020-04-09, BUY executed, price: 13.17, cost: 13.17, commission: 0.01
# 2020-04-09, BUY executed, price: 3.96, cost: 15.84, commission: 0.02
# 2020-04-09, BUY executed, price: 9.85, cost: 39.40, commission: 0.04
# 2020-04-09, BUY executed, price: 9.77, cost: 48.85, commission: 0.05
# 2020-04-09, BUY executed, price: 16.73, cost: 16.73, commission: 0.02
# 2020-04-09, BUY executed, price: 4.13, cost: 8.26, commission: 0.01
# 2020-04-09, BUY executed, price: 18.98, cost: 18.98, commission: 0.02
# 2020-04-09, BUY executed, price: 8.00, cost: 24.00, commission: 0.02
# 2020-04-09, SELL executed, price: 40.51, cost: 32.50, commission: 0.04
# 2020-04-09, BUY executed, price: 30.67, cost: 30.67, commission: 0.03
# 2020-04-09, BUY executed, price: 20.90, cost: 20.90, commission: 0.02
# 2020-04-09, BUY executed, price: 11.08, cost: 11.08, commission: 0.01
# 2020-04-09, BUY executed, price: 38.00, cost: 38.00, commission: 0.04
# 2020-04-09, BUY executed, price: 2.94, cost: 8.82, commission: 0.01
# 2020-04-09, BUY executed, price: 114.55, cost: 114.55, commission: 0.11
# 2020-04-09, BUY executed, price: 19.97, cost: 19.97, commission: 0.02
# 2020-04-09, BUY executed, price: 10.26, cost: 10.26, commission: 0.01
# 2020-04-09, BUY executed, price: 64.19, cost: 64.19, commission: 0.06
# 2020-04-09, BUY executed, price: 1.15, cost: 2.30, commission: 0.00
# 2020-04-09, BUY executed, price: 4.36, cost: 4.36, commission: 0.00
# 2020-04-09, BUY executed, price: 4.43, cost: 4.43, commission: 0.00
# 2020-04-09, BUY executed, price: 4.94, cost: 4.94, commission: 0.00
# 2020-04-09, BUY executed, price: 3.41, cost: 3.41, commission: 0.00
# 2020-04-09, BUY executed, price: 3.70, cost: 3.70, commission: 0.00
# 2020-04-09, BUY executed, price: 4.52, cost: 22.60, commission: 0.02
# 2020-04-09, BUY executed, price: 5.31, cost: 5.31, commission: 0.01
# 2020-04-09, BUY executed, price: 22.78, cost: 22.78, commission: 0.02
# 2020-04-09, BUY executed, price: 32.29, cost: 32.29, commission: 0.03
# 2020-04-09, BUY executed, price: 15.18, cost: 15.18, commission: 0.02
# 2020-04-09, BUY executed, price: 5.43, cost: 10.86, commission: 0.01
# 2020-04-09, BUY executed, price: 12.99, cost: 12.99, commission: 0.01
# 2020-04-09, BUY executed, price: 19.32, cost: 19.32, commission: 0.02
# 2020-04-09, BUY executed, price: 4.30, cost: 4.30, commission: 0.00
# 2020-04-09, BUY executed, price: 19.06, cost: 76.24, commission: 0.08
# 2020-04-09, BUY executed, price: 8.70, cost: 8.70, commission: 0.01
# 2020-04-09, BUY executed, price: 11.72, cost: 11.72, commission: 0.01
# 2020-04-09, BUY executed, price: 12.70, cost: 12.70, commission: 0.01
# 2020-04-09, BUY executed, price: 9.67, cost: 9.67, commission: 0.01
# 2020-04-09, BUY executed, price: 12.55, cost: 12.55, commission: 0.01
# 2020-04-09, BUY executed, price: 18.91, cost: 18.91, commission: 0.02
# 2020-04-09, BUY executed, price: 14.93, cost: 14.93, commission: 0.01
# 2020-04-09, BUY executed, price: 2.05, cost: 2.05, commission: 0.00
# 2020-04-09, BUY executed, price: 8.67, cost: 8.67, commission: 0.01
# 2020-04-09, BUY executed, price: 6.02, cost: 6.02, commission: 0.01
# 2020-04-09, BUY executed, price: 8.71, cost: 8.71, commission: 0.01
# 2020-04-09, BUY executed, price: 33.88, cost: 33.88, commission: 0.03
# 2020-04-09, BUY executed, price: 31.31, cost: 31.31, commission: 0.03
# 2020-04-09, BUY executed, price: 5.37, cost: 5.37, commission: 0.01
# 2020-04-09, BUY executed, price: 16.18, cost: 16.18, commission: 0.02
# 2020-04-09, BUY executed, price: 6.86, cost: 6.86, commission: 0.01
# 2020-04-09, BUY executed, price: 6.10, cost: 6.10, commission: 0.01
# 2020-04-09, BUY executed, price: 14.17, cost: 14.17, commission: 0.01
# 2020-04-09, BUY executed, price: 16.14, cost: 16.14, commission: 0.02
# 2020-04-09, BUY executed, price: 4.87, cost: 4.87, commission: 0.00
# 2020-04-09, BUY executed, price: 9.87, cost: 9.87, commission: 0.01
# 2020-04-09, BUY executed, price: 3.41, cost: 13.64, commission: 0.01
# 2020-04-09, BUY executed, price: 6.31, cost: 12.62, commission: 0.01
# 2020-04-09, BUY executed, price: 5.21, cost: 10.42, commission: 0.01
# 2020-04-09, BUY executed, price: 5.14, cost: 30.84, commission: 0.03
# 2020-04-09, BUY executed, price: 2.96, cost: 2.96, commission: 0.00
# 2020-04-09, BUY executed, price: 27.69, cost: 27.69, commission: 0.03
# 2020-04-09, BUY executed, price: 2.64, cost: 2.64, commission: 0.00
# 2020-04-09, BUY executed, price: 26.31, cost: 26.31, commission: 0.03
# 2020-04-09, BUY executed, price: 8.26, cost: 8.26, commission: 0.01
# 2020-04-09, BUY executed, price: 5.28, cost: 10.56, commission: 0.01
# 2020-04-09, BUY executed, price: 5.33, cost: 10.66, commission: 0.01
# 2020-04-09, BUY executed, price: 3.81, cost: 3.81, commission: 0.00
# 2020-04-09, BUY executed, price: 6.46, cost: 6.46, commission: 0.01
# 2020-04-09, BUY executed, price: 11.12, cost: 11.12, commission: 0.01
# 2020-04-09, BUY executed, price: 8.27, cost: 8.27, commission: 0.01
# 2020-04-09, BUY executed, price: 13.01, cost: 13.01, commission: 0.01
# 2020-04-09, BUY executed, price: 6.41, cost: 12.82, commission: 0.01
# 2020-04-09, BUY executed, price: 3.62, cost: 7.24, commission: 0.01
# 2020-04-09, BUY executed, price: 4.67, cost: 28.02, commission: 0.03
# 2020-04-09, BUY executed, price: 10.30, cost: 10.30, commission: 0.01
# 2020-04-09, BUY executed, price: 9.75, cost: 9.75, commission: 0.01
# 2020-04-09, BUY executed, price: 3.95, cost: 3.95, commission: 0.00
# 2020-04-09, BUY executed, price: 3.98, cost: 3.98, commission: 0.00
# 2020-04-09, BUY executed, price: 6.39, cost: 19.17, commission: 0.02
# 2020-04-09, BUY executed, price: 4.49, cost: 4.49, commission: 0.00
# 2020-04-09, BUY executed, price: 3.50, cost: 17.50, commission: 0.02
# 2020-04-09, BUY executed, price: 4.30, cost: 4.30, commission: 0.00
# 2020-04-09, BUY executed, price: 5.18, cost: 5.18, commission: 0.01
# 2020-04-09, BUY executed, price: 3.69, cost: 7.38, commission: 0.01
# 2020-04-09, BUY executed, price: 6.44, cost: 6.44, commission: 0.01
# 2020-05-13, SELL executed, price: 13.75, cost: 14.45, commission: 0.01
# 2020-05-13, SELL executed, price: 4.79, cost: 5.48, commission: 0.00
# 2020-05-13, SELL executed, price: 6.94, cost: 5.96, commission: 0.01
# 2020-05-13, SELL executed, price: 14.21, cost: 13.27, commission: 0.01
# 2020-05-13, BUY executed, price: 3.57, cost: 3.57, commission: 0.00
# 2020-05-13, BUY executed, price: 15.95, cost: 47.85, commission: 0.05
# 2020-05-13, SELL executed, price: 3.88, cost: 4.55, commission: 0.00
# 2020-05-13, SELL executed, price: 9.09, cost: 87.70, commission: 0.09
# 2020-05-13, SELL executed, price: 4.95, cost: 5.19, commission: 0.00
# 2020-05-13, SELL executed, price: 21.22, cost: 13.08, commission: 0.02
# 2020-05-13, SELL executed, price: 20.98, cost: 20.00, commission: 0.02
# 2020-05-13, SELL executed, price: 8.70, cost: 9.09, commission: 0.01
# 2020-05-13, SELL executed, price: 32.00, cost: 34.66, commission: 0.03
# 2020-05-13, SELL executed, price: 10.76, cost: 11.46, commission: 0.01
# 2020-05-13, SELL executed, price: 43.03, cost: 41.16, commission: 0.04
# 2020-05-13, SELL executed, price: 2.89, cost: 6.42, commission: 0.01
# 2020-05-13, SELL executed, price: 119.00, cost: 114.55, commission: 0.12
# 2020-05-13, SELL executed, price: 23.42, cost: 20.06, commission: 0.02
# 2020-05-13, BUY executed, price: 49.72, cost: 49.72, commission: 0.05
# 2020-05-13, SELL executed, price: 10.31, cost: 10.75, commission: 0.01
# 2020-05-13, SELL executed, price: 67.90, cost: 68.73, commission: 0.07
# 2020-05-13, SELL executed, price: 1.12, cost: 1.16, commission: 0.00
# 2020-05-13, SELL executed, price: 5.78, cost: 5.85, commission: 0.01
# 2020-05-13, SELL executed, price: 4.87, cost: 5.17, commission: 0.00
# 2020-05-13, SELL executed, price: 3.48, cost: 3.51, commission: 0.00
# 2020-05-13, SELL executed, price: 3.58, cost: 3.91, commission: 0.00
# 2020-05-13, BUY executed, price: 7.46, cost: 7.46, commission: 0.01
# 2020-05-13, SELL executed, price: 3.61, cost: 3.28, commission: 0.00
# 2020-05-13, SELL executed, price: 4.40, cost: 9.46, commission: 0.01
# 2020-05-13, BUY executed, price: 5.15, cost: 5.15, commission: 0.01
# 2020-05-13, SELL executed, price: 34.40, cost: 35.02, commission: 0.03
# 2020-05-13, SELL executed, price: 15.71, cost: 14.25, commission: 0.02
# 2020-05-13, SELL executed, price: 5.17, cost: 5.32, commission: 0.01
# 2020-05-13, SELL executed, price: 13.16, cost: 13.76, commission: 0.01
# 2020-05-13, SELL executed, price: 19.78, cost: 20.89, commission: 0.02
# 2020-05-13, SELL executed, price: 13.60, cost: 15.29, commission: 0.01
# 2020-05-13, SELL executed, price: 10.37, cost: 10.71, commission: 0.01
# 2020-05-13, SELL executed, price: 14.70, cost: 14.22, commission: 0.01
# 2020-05-13, SELL executed, price: 35.75, cost: 32.58, commission: 0.04
# 2020-05-13, SELL executed, price: 46.68, cost: 37.96, commission: 0.05
# 2020-05-13, SELL executed, price: 20.70, cost: 22.78, commission: 0.02
# 2020-05-13, SELL executed, price: 15.45, cost: 17.40, commission: 0.02
# 2020-05-13, SELL executed, price: 1.95, cost: 2.09, commission: 0.00
# 2020-05-13, SELL executed, price: 9.30, cost: 8.10, commission: 0.01
# 2020-05-13, SELL executed, price: 5.97, cost: 6.50, commission: 0.01
# 2020-05-13, BUY executed, price: 8.44, cost: 8.44, commission: 0.01
# 2020-05-13, BUY executed, price: 7.66, cost: 15.32, commission: 0.02
# 2020-05-13, SELL executed, price: 31.86, cost: 31.81, commission: 0.03
# 2020-05-13, SELL executed, price: 35.07, cost: 35.61, commission: 0.04
# 2020-05-13, SELL executed, price: 34.90, cost: 32.11, commission: 0.03
# 2020-05-13, SELL executed, price: 15.94, cost: 16.07, commission: 0.02
# 2020-05-13, SELL executed, price: 6.80, cost: 7.77, commission: 0.01
# 2020-05-13, SELL executed, price: 5.87, cost: 7.28, commission: 0.01
# 2020-05-13, BUY executed, price: 8.10, cost: 8.10, commission: 0.01
# 2020-05-13, SELL executed, price: 16.18, cost: 17.41, commission: 0.02
# 2020-05-13, SELL executed, price: 4.91, cost: 5.21, commission: 0.00
# 2020-05-13, SELL executed, price: 9.63, cost: 8.80, commission: 0.01
# 2020-05-13, SELL executed, price: 3.41, cost: 20.28, commission: 0.02
# 2020-05-13, SELL executed, price: 6.32, cost: 13.57, commission: 0.01
# 2020-05-13, SELL executed, price: 5.13, cost: 10.46, commission: 0.01
# 2020-05-13, SELL executed, price: 5.12, cost: 32.43, commission: 0.03
# 2020-05-13, SELL executed, price: 29.30, cost: 32.72, commission: 0.03
# 2020-05-13, SELL executed, price: 2.60, cost: 2.44, commission: 0.00
# 2020-05-13, SELL executed, price: 27.72, cost: 29.68, commission: 0.03
# 2020-05-13, SELL executed, price: 8.57, cost: 7.65, commission: 0.01
# 2020-05-13, SELL executed, price: 5.15, cost: 10.93, commission: 0.01
# 2020-05-13, SELL executed, price: 5.15, cost: 5.23, commission: 0.01
# 2020-05-13, SELL executed, price: 3.62, cost: 3.82, commission: 0.00
# 2020-05-13, SELL executed, price: 11.13, cost: 11.31, commission: 0.01
# 2020-05-13, SELL executed, price: 8.11, cost: 7.58, commission: 0.01
# 2020-05-13, SELL executed, price: 13.10, cost: 15.99, commission: 0.01
# 2020-05-13, SELL executed, price: 6.27, cost: 7.53, commission: 0.01
# 2020-05-13, SELL executed, price: 3.69, cost: 7.53, commission: 0.01
# 2020-05-13, SELL executed, price: 4.43, cost: 5.22, commission: 0.00
# 2020-05-13, SELL executed, price: 10.01, cost: 10.08, commission: 0.01
# 2020-05-13, SELL executed, price: 3.88, cost: 4.06, commission: 0.00
# 2020-05-13, SELL executed, price: 6.34, cost: 26.39, commission: 0.03
# 2020-05-13, SELL executed, price: 3.45, cost: 17.45, commission: 0.02
# 2020-05-13, SELL executed, price: 4.21, cost: 4.37, commission: 0.00
# 2020-05-13, SELL executed, price: 5.09, cost: 5.53, commission: 0.01
# 2020-05-13, BUY executed, price: 39.00, cost: 39.00, commission: 0.04
# 2020-05-13, SELL executed, price: 169.48, cost: 103.59, commission: 0.17
# 2020-05-13, BUY executed, price: 24.57, cost: 24.57, commission: 0.02
# 2020-05-13, SELL executed, price: 3.52, cost: 3.82, commission: 0.00
# 2020-05-13, BUY executed, price: 17.49, cost: 69.96, commission: 0.07
# 2020-06-11, SELL executed, price: 13.38, cost: 14.45, commission: 0.01
# 2020-06-11, SELL executed, price: 5.98, cost: 5.48, commission: 0.01
# 2020-06-11, BUY executed, price: 6.39, cost: 6.39, commission: 0.01
# 2020-06-11, SELL executed, price: 4.46, cost: 4.42, commission: 0.00
# 2020-06-11, SELL executed, price: 5.80, cost: 5.75, commission: 0.01
# 2020-06-11, SELL executed, price: 10.12, cost: 10.20, commission: 0.01
# 2020-06-11, SELL executed, price: 1.94, cost: 1.99, commission: 0.00
# 2020-06-11, SELL executed, price: 4.75, cost: 18.21, commission: 0.02
# 2020-06-11, SELL executed, price: 11.51, cost: 9.21, commission: 0.01
# 2020-06-11, SELL executed, price: 16.74, cost: 16.45, commission: 0.02
# 2020-06-11, SELL executed, price: 27.71, cost: 23.37, commission: 0.03
# 2020-06-11, SELL executed, price: 5.29, cost: 5.19, commission: 0.01
# 2020-06-11, BUY executed, price: 19.61, cost: 19.61, commission: 0.02
# 2020-06-11, SELL executed, price: 53.43, cost: 44.85, commission: 0.05
# 2020-06-11, SELL executed, price: 54.64, cost: 41.52, commission: 0.05
# 2020-06-11, SELL executed, price: 12.74, cost: 10.47, commission: 0.01
# 2020-06-11, SELL executed, price: 61.87, cost: 59.20, commission: 0.06
# 2020-06-11, SELL executed, price: 10.90, cost: 11.00, commission: 0.01
# 2020-06-11, BUY executed, price: 69.40, cost: 138.80, commission: 0.14
# 2020-06-11, SELL executed, price: 2.98, cost: 3.21, commission: 0.00
# 2020-06-11, BUY executed, price: 43.06, cost: 86.12, commission: 0.09
# 2020-06-11, BUY executed, price: 41.70, cost: 41.70, commission: 0.04
# 2020-06-11, BUY executed, price: 15.71, cost: 31.42, commission: 0.03
# 2020-06-11, SELL executed, price: 53.28, cost: 50.10, commission: 0.05
# 2020-06-11, SELL executed, price: 150.10, cost: 49.72, commission: 0.15
# 2020-06-11, SELL executed, price: 1.08, cost: 1.16, commission: 0.00
# 2020-06-11, SELL executed, price: 4.26, cost: 4.89, commission: 0.00
# 2020-06-11, SELL executed, price: 5.74, cost: 5.85, commission: 0.01
# 2020-06-11, SELL executed, price: 4.21, cost: 4.65, commission: 0.00
# 2020-06-11, SELL executed, price: 5.53, cost: 5.77, commission: 0.01
# 2020-06-11, SELL executed, price: 4.44, cost: 4.63, commission: 0.00
# 2020-06-11, SELL executed, price: 8.68, cost: 8.87, commission: 0.01
# 2020-06-11, SELL executed, price: 4.98, cost: 6.80, commission: 0.01
# 2020-06-11, SELL executed, price: 155.50, cost: 131.30, commission: 0.16
# 2020-06-11, BUY executed, price: 15.97, cost: 15.97, commission: 0.02
# 2020-06-11, BUY executed, price: 8.90, cost: 17.80, commission: 0.02
# 2020-06-11, BUY executed, price: 35.82, cost: 71.64, commission: 0.07
# 2020-06-11, SELL executed, price: 9.15, cost: 8.77, commission: 0.01
# 2020-06-11, SELL executed, price: 7.89, cost: 7.92, commission: 0.01
# 2020-06-11, SELL executed, price: 17.88, cost: 17.68, commission: 0.02
# 2020-06-11, BUY executed, price: 11.17, cost: 134.04, commission: 0.13
# 2020-06-11, SELL executed, price: 7.03, cost: 7.30, commission: 0.01
# 2020-06-11, SELL executed, price: 3.43, cost: 3.22, commission: 0.00
# 2020-06-11, SELL executed, price: 4.93, cost: 5.21, commission: 0.00
# 2020-06-11, BUY executed, price: 8.70, cost: 8.70, commission: 0.01
# 2020-06-11, SELL executed, price: 3.40, cost: 16.90, commission: 0.02
# 2020-06-11, SELL executed, price: 75.21, cost: 80.21, commission: 0.08
# 2020-06-11, SELL executed, price: 6.34, cost: 6.78, commission: 0.01
# 2020-06-11, SELL executed, price: 5.13, cost: 5.23, commission: 0.01
# 2020-06-11, SELL executed, price: 5.27, cost: 32.43, commission: 0.03
# 2020-06-11, SELL executed, price: 2.82, cost: 3.02, commission: 0.00
# 2020-06-11, SELL executed, price: 28.75, cost: 29.68, commission: 0.03
# 2020-06-11, SELL executed, price: 5.04, cost: 5.23, commission: 0.01
# 2020-06-11, SELL executed, price: 19.11, cost: 19.00, commission: 0.02
# 2020-06-11, SELL executed, price: 6.60, cost: 15.06, commission: 0.01
# 2020-06-11, SELL executed, price: 3.79, cost: 7.53, commission: 0.01
# 2020-06-11, SELL executed, price: 7.89, cost: 8.20, commission: 0.01
# 2020-06-11, SELL executed, price: 4.31, cost: 10.44, commission: 0.01
# 2020-06-11, SELL executed, price: 4.08, cost: 4.06, commission: 0.00
# 2020-06-11, SELL executed, price: 3.94, cost: 4.21, commission: 0.00
# 2020-06-11, SELL executed, price: 6.40, cost: 26.39, commission: 0.03
# 2020-06-11, SELL executed, price: 3.50, cost: 17.45, commission: 0.02
# 2020-06-11, SELL executed, price: 5.08, cost: 5.53, commission: 0.01
# 2020-06-11, BUY executed, price: 81.30, cost: 81.30, commission: 0.08
# 2020-06-11, SELL executed, price: 137.50, cost: 24.57, commission: 0.14
# 2020-06-11, BUY executed, price: 16.50, cost: 66.00, commission: 0.07
# 2020-07-14, SELL executed, price: 14.90, cost: 14.45, commission: 0.01
# 2020-07-14, SELL executed, price: 29.14, cost: 27.24, commission: 0.03
# 2020-07-14, SELL executed, price: 46.00, cost: 38.55, commission: 0.05
# 2020-07-14, SELL executed, price: 7.00, cost: 10.96, commission: 0.01
# 2020-07-14, SELL executed, price: 7.98, cost: 11.98, commission: 0.02
# 2020-07-14, SELL executed, price: 6.23, cost: 22.11, commission: 0.03
# 2020-07-14, SELL executed, price: 5.70, cost: 4.90, commission: 0.01
# 2020-07-14, SELL executed, price: 63.86, cost: 52.30, commission: 0.06
# 2020-07-14, SELL executed, price: 15.95, cost: 13.27, commission: 0.02
# 2020-07-14, SELL executed, price: 6.79, cost: 5.75, commission: 0.01
# 2020-07-14, SELL executed, price: 6.87, cost: 9.44, commission: 0.01
# 2020-07-14, SELL executed, price: 109.25, cost: 84.14, commission: 0.11
# 2020-07-14, SELL executed, price: 125.00, cost: 74.00, commission: 0.12
# 2020-07-14, BUY executed, price: 8.16, cost: 40.80, commission: 0.04
# 2020-07-14, SELL executed, price: 13.42, cost: 8.99, commission: 0.01
# 2020-07-14, SELL executed, price: 2.35, cost: 3.98, commission: 0.00
# 2020-07-14, SELL executed, price: 59.43, cost: 62.00, commission: 0.06
# 2020-07-14, SELL executed, price: 18.90, cost: 19.76, commission: 0.02
# 2020-07-14, SELL executed, price: 5.29, cost: 13.66, commission: 0.02
# 2020-07-14, SELL executed, price: 23.29, cost: 15.53, commission: 0.02
# 2020-07-14, SELL executed, price: 16.95, cost: 27.88, commission: 0.03
# 2020-07-14, SELL executed, price: 14.68, cost: 9.21, commission: 0.01
# 2020-07-14, SELL executed, price: 6.68, cost: 8.50, commission: 0.01
# 2020-07-14, SELL executed, price: 218.30, cost: 119.50, commission: 0.22
# 2020-07-14, SELL executed, price: 34.10, cost: 19.15, commission: 0.03
# 2020-07-14, SELL executed, price: 49.29, cost: 32.64, commission: 0.05
# 2020-07-14, SELL executed, price: 17.05, cost: 11.88, commission: 0.02
# 2020-07-14, BUY executed, price: 4.45, cost: 4.45, commission: 0.00
# 2020-07-14, SELL executed, price: 31.87, cost: 35.19, commission: 0.03
# 2020-07-14, SELL executed, price: 7.53, cost: 7.41, commission: 0.01
# 2020-07-14, SELL executed, price: 19.47, cost: 16.45, commission: 0.02
# 2020-07-14, SELL executed, price: 6.00, cost: 10.39, commission: 0.01
# 2020-07-14, SELL executed, price: 136.00, cost: 54.80, commission: 0.14
# 2020-07-14, SELL executed, price: 25.14, cost: 20.95, commission: 0.03
# 2020-07-14, SELL executed, price: 27.93, cost: 16.07, commission: 0.03
# 2020-07-14, SELL executed, price: 33.90, cost: 20.00, commission: 0.03
# 2020-07-14, SELL executed, price: 10.90, cost: 9.09, commission: 0.01
# 2020-07-14, SELL executed, price: 136.00, cost: 102.00, commission: 0.14
# 2020-07-14, SELL executed, price: 33.32, cost: 26.40, commission: 0.03
# 2020-07-14, SELL executed, price: 37.44, cost: 34.66, commission: 0.04
# 2020-07-14, SELL executed, price: 23.50, cost: 26.00, commission: 0.02
# 2020-07-14, SELL executed, price: 22.20, cost: 15.56, commission: 0.02
# 2020-07-14, SELL executed, price: 30.20, cost: 25.18, commission: 0.03
# 2020-07-14, BUY executed, price: 59.00, cost: 59.00, commission: 0.06
# 2020-07-14, SELL executed, price: 16.20, cost: 10.47, commission: 0.02
# 2020-07-14, SELL executed, price: 22.98, cost: 15.32, commission: 0.02
# 2020-07-14, SELL executed, price: 9.64, cost: 7.74, commission: 0.01
# 2020-07-14, SELL executed, price: 14.98, cost: 22.92, commission: 0.03
# 2020-07-14, SELL executed, price: 3.20, cost: 16.05, commission: 0.02
# 2020-07-14, SELL executed, price: 56.70, cost: 49.21, commission: 0.06
# 2020-07-14, SELL executed, price: 26.69, cost: 29.50, commission: 0.05
# 2020-07-14, SELL executed, price: 49.60, cost: 28.39, commission: 0.05
# 2020-07-14, SELL executed, price: 14.88, cost: 10.00, commission: 0.01
# 2020-07-14, SELL executed, price: 35.00, cost: 18.73, commission: 0.04
# 2020-07-14, BUY executed, price: 26.02, cost: 26.02, commission: 0.03
# 2020-07-14, SELL executed, price: 11.61, cost: 32.24, commission: 0.03
# 2020-07-14, SELL executed, price: 1.25, cost: 8.12, commission: 0.01
# 2020-07-14, SELL executed, price: 4.74, cost: 9.78, commission: 0.01
# 2020-07-14, SELL executed, price: 6.75, cost: 14.18, commission: 0.01
# 2020-07-14, SELL executed, price: 5.83, cost: 17.55, commission: 0.02
# 2020-07-14, SELL executed, price: 4.95, cost: 13.96, commission: 0.01
# 2020-07-14, SELL executed, price: 5.29, cost: 15.52, commission: 0.02
# 2020-07-14, SELL executed, price: 3.70, cost: 7.01, commission: 0.01
# 2020-07-14, SELL executed, price: 4.02, cost: 11.74, commission: 0.01
# 2020-07-14, SELL executed, price: 8.00, cost: 5.91, commission: 0.01
# 2020-07-14, SELL executed, price: 3.80, cost: 3.28, commission: 0.00
# 2020-07-14, SELL executed, price: 4.15, cost: 37.85, commission: 0.03
# 2020-07-14, BUY executed, price: 5.69, cost: 11.38, commission: 0.01
# 2020-07-14, SELL executed, price: 32.00, cost: 44.47, commission: 0.06
# 2020-07-14, SELL executed, price: 21.60, cost: 15.66, commission: 0.02
# 2020-07-14, SELL executed, price: 37.07, cost: 70.03, commission: 0.07
# 2020-07-14, SELL executed, price: 4.36, cost: 3.32, commission: 0.00
# 2020-07-14, SELL executed, price: 17.20, cost: 14.25, commission: 0.02
# ...
# 2025-09-18, SELL executed, price: 2.49, cost: 2.34, commission: 0.00
# 2025-09-18, SELL executed, price: 8.88, cost: 5.52, commission: 0.01
# 2025-09-18, SELL executed, price: 28.13, cost: 29.88, commission: 0.03
# 2025-09-18, SELL executed, price: 24.68, cost: 14.13, commission: 0.05
# 2025-09-18, SELL executed, price: 8.34, cost: 7.43, commission: 0.01
# 2025-09-18, SELL executed, price: 3.04, cost: 2.61, commission: 0.00
# 2025-09-18, SELL executed, price: 8.99, cost: 19.64, commission: 0.03
# 2025-09-18, SELL executed, price: 8.86, cost: 5.87, commission: 0.01
# 2025-09-18, SELL executed, price: 5.41, cost: 10.86, commission: 0.02
# 2025-09-18, SELL executed, price: 7.61, cost: 5.59, commission: 0.01
# 2025-09-18, SELL executed, price: 16.20, cost: 22.30, commission: 0.02
# 2025-09-18, SELL executed, price: 12.60, cost: 4.96, commission: 0.01
# 2025-09-18, SELL executed, price: 5.37, cost: 5.90, commission: 0.01
# 2025-09-18, SELL executed, price: 250.06, cost: 49.65, commission: 0.25
# 2025-09-18, SELL executed, price: 150.90, cost: 157.30, commission: 0.15
# 2025-09-18, SELL executed, price: 30.46, cost: 53.97, commission: 0.03
# 2025-09-18, SELL executed, price: 119.98, cost: 60.48, commission: 0.12
# 2025-10-27, BUY executed, price: 9.15, cost: 9.15, commission: 0.01
# 2025-10-27, SELL executed, price: 14.21, cost: 13.77, commission: 0.01
# 2025-10-27, SELL executed, price: 10.32, cost: 7.50, commission: 0.01
# 2025-10-27, BUY executed, price: 7.53, cost: 7.53, commission: 0.01
# 2025-10-27, SELL executed, price: 122.00, cost: 13.08, commission: 0.12
# 2025-10-27, BUY executed, price: 57.60, cost: 57.60, commission: 0.06
# 2025-10-27, SELL executed, price: 4.00, cost: 3.23, commission: 0.00
# 2025-10-27, BUY executed, price: 12.92, cost: 12.92, commission: 0.01
# 2025-10-27, SELL executed, price: 2.64, cost: 1.49, commission: 0.00
# 2025-10-27, SELL executed, price: 4.11, cost: 5.18, commission: 0.00
# 2025-10-27, SELL executed, price: 7.15, cost: 5.65, commission: 0.01
# 2025-10-27, BUY executed, price: 12.36, cost: 12.36, commission: 0.01
# 2025-10-27, SELL executed, price: 5.52, cost: 4.83, commission: 0.01
# 2025-10-27, SELL executed, price: 6.58, cost: 5.90, commission: 0.01
# 2025-10-27, SELL executed, price: 29.87, cost: 13.76, commission: 0.03
# 2025-10-27, SELL executed, price: 4.86, cost: 4.56, commission: 0.00
# 2025-10-27, SELL executed, price: 14.81, cost: 15.57, commission: 0.01
# 2025-10-27, SELL executed, price: 40.30, cost: 19.35, commission: 0.04
# 2025-10-27, SELL executed, price: 22.19, cost: 9.74, commission: 0.02
# 2025-10-27, SELL executed, price: 63.93, cost: 48.77, commission: 0.06
# 2025-10-27, SELL executed, price: 4.31, cost: 6.37, commission: 0.00
# 2025-10-27, SELL executed, price: 7.00, cost: 9.35, commission: 0.01
# 2025-10-27, SELL executed, price: 10.85, cost: 6.03, commission: 0.01
# 2025-10-27, SELL executed, price: 11.38, cost: 8.67, commission: 0.01
# 2025-10-27, SELL executed, price: 69.26, cost: 17.89, commission: 0.07
# 2025-10-27, SELL executed, price: 20.56, cost: 18.03, commission: 0.02
# 2025-10-27, SELL executed, price: 18.94, cost: 17.19, commission: 0.02
# 2025-10-27, SELL executed, price: 9.63, cost: 8.18, commission: 0.01
# 2025-10-27, SELL executed, price: 9.14, cost: 12.14, commission: 0.01
# 2025-10-27, SELL executed, price: 7.70, cost: 9.90, commission: 0.01
# 2025-10-27, SELL executed, price: 7.92, cost: 27.26, commission: 0.06
# 2025-10-27, SELL executed, price: 8.75, cost: 6.27, commission: 0.01
# 2025-10-27, SELL executed, price: 8.75, cost: 6.33, commission: 0.01
# 2025-10-27, SELL executed, price: 7.21, cost: 5.58, commission: 0.01
# 2025-10-27, SELL executed, price: 6.60, cost: 6.37, commission: 0.01
# 2025-10-27, SELL executed, price: 7.80, cost: 21.13, commission: 0.03
# 2025-10-27, SELL executed, price: 9.27, cost: 4.45, commission: 0.01
# 2025-10-27, SELL executed, price: 3.80, cost: 2.90, commission: 0.00
# 2025-10-27, SELL executed, price: 44.30, cost: 30.91, commission: 0.04
# 2025-10-27, SELL executed, price: 5.72, cost: 4.87, commission: 0.01
# 2025-10-27, SELL executed, price: 8.92, cost: 8.17, commission: 0.01
# 2025-10-27, SELL executed, price: 3.52, cost: 3.60, commission: 0.00
# 2025-10-27, SELL executed, price: 9.03, cost: 16.84, commission: 0.03
# 2025-10-27, SELL executed, price: 2.48, cost: 2.34, commission: 0.00
# 2025-10-27, SELL executed, price: 13.10, cost: 6.60, commission: 0.01
# 2025-10-27, SELL executed, price: 30.12, cost: 7.06, commission: 0.03
# 2025-10-27, SELL executed, price: 9.35, cost: 19.64, commission: 0.03
# 2025-10-27, SELL executed, price: 5.51, cost: 10.86, commission: 0.02
# 2025-10-27, SELL executed, price: 17.49, cost: 9.93, commission: 0.03
# 2025-11-25, BUY executed, price: 39.02, cost: 39.02, commission: 0.04
# 2025-11-25, BUY executed, price: 4.09, cost: 4.09, commission: 0.00
# 2025-11-25, BUY executed, price: 5.15, cost: 5.15, commission: 0.01
# 2025-11-25, BUY executed, price: 9.09, cost: 9.09, commission: 0.01
# 2025-11-25, BUY executed, price: 4.92, cost: 4.92, commission: 0.00
# 2025-11-25, BUY executed, price: 3.83, cost: 7.66, commission: 0.01
# 2025-11-25, BUY executed, price: 10.18, cost: 10.18, commission: 0.01
# 2025-11-25, BUY executed, price: 12.25, cost: 12.25, commission: 0.01
# 2025-11-25, BUY executed, price: 13.16, cost: 13.16, commission: 0.01
# 2025-11-25, BUY executed, price: 3.77, cost: 7.54, commission: 0.01
# 2025-11-25, BUY executed, price: 11.57, cost: 11.57, commission: 0.01
# 2025-11-25, BUY executed, price: 23.49, cost: 23.49, commission: 0.02
# 2025-11-25, BUY executed, price: 26.77, cost: 26.77, commission: 0.03
# 2025-11-25, BUY executed, price: 11.53, cost: 23.06, commission: 0.02
# 2025-11-25, BUY executed, price: 2.44, cost: 4.88, commission: 0.00
# 2025-11-25, BUY executed, price: 6.94, cost: 6.94, commission: 0.01
# 2025-11-25, BUY executed, price: 4.06, cost: 4.06, commission: 0.00
# 2025-11-25, BUY executed, price: 5.51, cost: 5.51, commission: 0.01
# 2025-11-25, BUY executed, price: 7.19, cost: 7.19, commission: 0.01
# 2025-11-25, BUY executed, price: 5.02, cost: 5.02, commission: 0.01
# 2025-11-25, BUY executed, price: 9.40, cost: 9.40, commission: 0.01
# 2025-11-25, BUY executed, price: 5.06, cost: 5.06, commission: 0.01
# 2025-11-25, BUY executed, price: 5.85, cost: 5.85, commission: 0.01
# 2025-11-25, BUY executed, price: 6.93, cost: 6.93, commission: 0.01
# 2025-11-25, BUY executed, price: 27.47, cost: 27.47, commission: 0.03
# 2025-11-25, BUY executed, price: 20.57, cost: 20.57, commission: 0.02
# 2025-11-25, BUY executed, price: 6.99, cost: 6.99, commission: 0.01
# 2025-11-25, BUY executed, price: 33.60, cost: 33.60, commission: 0.03
# 2025-11-25, BUY executed, price: 14.87, cost: 14.87, commission: 0.01
# 2025-11-25, BUY executed, price: 13.90, cost: 13.90, commission: 0.01
# 2025-11-25, BUY executed, price: 36.33, cost: 36.33, commission: 0.04
# 2025-11-25, BUY executed, price: 35.43, cost: 35.43, commission: 0.04
# 2025-11-25, BUY executed, price: 60.59, cost: 60.59, commission: 0.06
# 2025-11-25, BUY executed, price: 4.19, cost: 4.19, commission: 0.00
# 2025-11-25, BUY executed, price: 6.63, cost: 6.63, commission: 0.01
# 2025-11-25, BUY executed, price: 10.69, cost: 10.69, commission: 0.01
# 2025-11-25, BUY executed, price: 6.11, cost: 12.22, commission: 0.01
# 2025-11-25, BUY executed, price: 5.54, cost: 5.54, commission: 0.01
# 2025-11-25, BUY executed, price: 11.37, cost: 11.37, commission: 0.01
# 2025-11-25, SELL executed, price: 17.70, cost: 64.51, commission: 0.07
# 2025-11-25, BUY executed, price: 25.00, cost: 25.00, commission: 0.03
# 2025-11-25, BUY executed, price: 6.48, cost: 6.48, commission: 0.01
# 2025-11-25, BUY executed, price: 7.49, cost: 7.49, commission: 0.01
# 2025-11-25, BUY executed, price: 56.36, cost: 56.36, commission: 0.06
# 2025-11-25, BUY executed, price: 21.05, cost: 21.05, commission: 0.02
# 2025-11-25, BUY executed, price: 18.82, cost: 18.82, commission: 0.02
# 2025-11-25, BUY executed, price: 9.84, cost: 9.84, commission: 0.01
# 2025-11-25, BUY executed, price: 8.53, cost: 8.53, commission: 0.01
# 2025-11-25, BUY executed, price: 9.00, cost: 9.00, commission: 0.01
# 2025-11-25, BUY executed, price: 7.99, cost: 31.96, commission: 0.03
# 2025-11-25, BUY executed, price: 8.43, cost: 8.43, commission: 0.01
# 2025-11-25, BUY executed, price: 8.37, cost: 8.37, commission: 0.01
# 2025-11-25, SELL executed, price: 13.87, cost: 16.03, commission: 0.01
# 2025-11-25, BUY executed, price: 6.69, cost: 6.69, commission: 0.01
# 2025-11-25, BUY executed, price: 5.44, cost: 5.44, commission: 0.01
# 2025-11-25, BUY executed, price: 8.18, cost: 16.36, commission: 0.02
# 2025-11-25, BUY executed, price: 17.78, cost: 17.78, commission: 0.02
# 2025-11-25, BUY executed, price: 3.22, cost: 6.44, commission: 0.01
# 2025-11-25, BUY executed, price: 43.06, cost: 43.06, commission: 0.04
# 2025-11-25, BUY executed, price: 21.72, cost: 21.72, commission: 0.02
# 2025-11-25, BUY executed, price: 5.80, cost: 11.60, commission: 0.01
# 2025-11-25, BUY executed, price: 5.27, cost: 10.54, commission: 0.01
# 2025-11-25, BUY executed, price: 5.46, cost: 5.46, commission: 0.01
# 2025-11-25, BUY executed, price: 62.25, cost: 62.25, commission: 0.06
# 2025-11-25, BUY executed, price: 6.85, cost: 6.85, commission: 0.01
# 2025-11-25, BUY executed, price: 7.27, cost: 7.27, commission: 0.01
# 2025-11-25, BUY executed, price: 8.53, cost: 8.53, commission: 0.01
# 2025-11-25, BUY executed, price: 5.08, cost: 5.08, commission: 0.01
# 2025-11-25, BUY executed, price: 3.60, cost: 3.60, commission: 0.00
# 2025-11-25, BUY executed, price: 2.36, cost: 4.72, commission: 0.00
# 2025-11-25, BUY executed, price: 27.14, cost: 27.14, commission: 0.03
# 2025-11-25, BUY executed, price: 13.79, cost: 13.79, commission: 0.01
# 2025-11-25, BUY executed, price: 28.47, cost: 28.47, commission: 0.03
# 2025-11-25, BUY executed, price: 7.82, cost: 7.82, commission: 0.01
# 2025-11-25, BUY executed, price: 3.08, cost: 3.08, commission: 0.00
# 2025-11-25, BUY executed, price: 9.73, cost: 19.46, commission: 0.02
# 2025-11-25, BUY executed, price: 8.72, cost: 8.72, commission: 0.01
# 2025-11-25, SELL executed, price: 6.15, cost: 3.62, commission: 0.01
# 2025-11-25, SELL executed, price: 35.04, cost: 270.17, commission: 0.18
# 2025-11-25, BUY executed, price: 7.78, cost: 7.78, commission: 0.01
# 2025-11-25, BUY executed, price: 14.08, cost: 14.08, commission: 0.01
# 2025-11-25, BUY executed, price: 15.70, cost: 15.70, commission: 0.02
# 2025-11-25, BUY executed, price: 5.21, cost: 5.21, commission: 0.01
# 2025-12-24, BUY executed, price: 4.76, cost: 4.76, commission: 0.00
# 2025-12-24, SELL executed, price: 4.48, cost: 4.72, commission: 0.00
# 2025-12-24, SELL executed, price: 5.22, cost: 4.51, commission: 0.01
# 2025-12-24, SELL executed, price: 10.30, cost: 9.77, commission: 0.01
# 2025-12-24, SELL executed, price: 79.43, cost: 52.17, commission: 0.08
# 2025-12-24, SELL executed, price: 9.08, cost: 7.51, commission: 0.01
# 2025-12-24, SELL executed, price: 5.60, cost: 3.38, commission: 0.01
# 2025-12-24, SELL executed, price: 4.03, cost: 4.43, commission: 0.00
# 2025-12-24, SELL executed, price: 28.60, cost: 31.85, commission: 0.03
# 2025-12-24, SELL executed, price: 24.64, cost: 20.44, commission: 0.02
# 2025-12-24, SELL executed, price: 15.88, cost: 8.90, commission: 0.02
# 2025-12-24, SELL executed, price: 3.82, cost: 3.25, commission: 0.00
# 2025-12-24, SELL executed, price: 28.43, cost: 21.05, commission: 0.03
# 2025-12-24, SELL executed, price: 6.83, cost: 6.55, commission: 0.01
# 2025-12-24, BUY executed, price: 3.83, cost: 3.83, commission: 0.00
# 2025-12-24, SELL executed, price: 5.57, cost: 4.79, commission: 0.01
# 2025-12-24, SELL executed, price: 7.16, cost: 5.72, commission: 0.01
# 2025-12-24, SELL executed, price: 5.14, cost: 3.88, commission: 0.01
# 2025-12-24, SELL executed, price: 9.26, cost: 5.27, commission: 0.01
# 2025-12-24, SELL executed, price: 5.23, cost: 4.42, commission: 0.01
# 2025-12-24, SELL executed, price: 5.90, cost: 9.69, commission: 0.01
# 2025-12-24, SELL executed, price: 7.52, cost: 5.95, commission: 0.01
# 2025-12-24, SELL executed, price: 28.61, cost: 23.00, commission: 0.03
# 2025-12-24, SELL executed, price: 9.85, cost: 6.80, commission: 0.01
# 2025-12-24, SELL executed, price: 22.95, cost: 11.66, commission: 0.02
# 2025-12-24, SELL executed, price: 5.65, cost: 4.56, commission: 0.01
# 2025-12-24, SELL executed, price: 5.06, cost: 2.73, commission: 0.01
# 2025-12-24, SELL executed, price: 19.96, cost: 16.01, commission: 0.02
# 2025-12-24, SELL executed, price: 42.90, cost: 23.59, commission: 0.04
# 2025-12-24, SELL executed, price: 5.26, cost: 4.11, commission: 0.01
# 2025-12-24, SELL executed, price: 41.51, cost: 30.14, commission: 0.04
# 2025-12-24, BUY executed, price: 12.56, cost: 12.56, commission: 0.01
# 2025-12-24, SELL executed, price: 5.91, cost: 2.72, commission: 0.01
# 2025-12-24, BUY executed, price: 6.58, cost: 6.58, commission: 0.01
# 2025-12-24, SELL executed, price: 6.33, cost: 7.59, commission: 0.01
# 2025-12-24, SELL executed, price: 11.35, cost: 8.86, commission: 0.01
# 2025-12-24, BUY executed, price: 17.78, cost: 71.12, commission: 0.07
# 2025-12-24, SELL executed, price: 26.67, cost: 28.47, commission: 0.03
# 2025-12-24, SELL executed, price: 6.44, cost: 5.49, commission: 0.01
# 2025-12-24, SELL executed, price: 7.66, cost: 7.87, commission: 0.01
# 2025-12-24, SELL executed, price: 21.06, cost: 18.19, commission: 0.02
# 2025-12-24, SELL executed, price: 20.87, cost: 17.29, commission: 0.02
# 2025-12-24, SELL executed, price: 9.90, cost: 8.29, commission: 0.01
# 2025-12-24, SELL executed, price: 8.18, cost: 9.83, commission: 0.01
# 2025-12-24, SELL executed, price: 69.17, cost: 68.57, commission: 0.07
# 2025-12-24, SELL executed, price: 9.20, cost: 6.38, commission: 0.01
# 2025-12-24, BUY executed, price: 10.47, cost: 10.47, commission: 0.01
# 2025-12-24, SELL executed, price: 7.26, cost: 6.40, commission: 0.01
# 2025-12-24, SELL executed, price: 7.92, cost: 5.31, commission: 0.01
# 2025-12-24, SELL executed, price: 11.00, cost: 4.45, commission: 0.01
# 2025-12-24, SELL executed, price: 17.91, cost: 19.68, commission: 0.02
# 2025-12-24, SELL executed, price: 46.32, cost: 31.55, commission: 0.05
# 2025-12-24, SELL executed, price: 22.03, cost: 19.38, commission: 0.02
# 2025-12-24, BUY executed, price: 5.45, cost: 5.45, commission: 0.01
# 2025-12-24, SELL executed, price: 5.20, cost: 5.27, commission: 0.01
# 2025-12-24, SELL executed, price: 5.20, cost: 6.69, commission: 0.01
# 2025-12-24, SELL executed, price: 9.87, cost: 5.61, commission: 0.01
# 2025-12-24, SELL executed, price: 2.37, cost: 2.34, commission: 0.00
# 2025-12-24, SELL executed, price: 27.90, cost: 28.97, commission: 0.03
# 2025-12-24, SELL executed, price: 32.54, cost: 8.13, commission: 0.03
# 2025-12-24, SELL executed, price: 3.04, cost: 2.62, commission: 0.00
# 2025-12-24, SELL executed, price: 8.69, cost: 6.00, commission: 0.01
# 2025-12-24, BUY executed, price: 5.70, cost: 5.70, commission: 0.01
# 2025-12-24, BUY executed, price: 35.48, cost: 177.40, commission: 0.18
# 2025-12-24, SELL executed, price: 18.75, cost: 5.53, commission: 0.02
# 2025-12-24, SELL executed, price: 5.43, cost: 5.85, commission: 0.01
# 2025-12-24, BUY executed, price: 21.66, cost: 21.66, commission: 0.02
# Final Portfolio Value: 120484.41
# Total Return: 0.2048
# Benchmark Return: 0.1234
# OrderedDict([(2020, 0.12821578389999977),
#              (2021, 0.004639541189455976),
#              (2022, -0.06287820398812094),
#              (2023, -0.011270542783488713),
#              (2024, 0.09287210152394376),
#              (2025, 0.04974924189707863)])
# OrderedDict({'sharperatio': 0.3657402653572989})
# OrderedDict([(2020, 0.12821578389999977),
#              (2021, 0.004639541189455976),
#              (2022, -0.06287820398812094),
#              (2023, -0.011270542783488713),
#              (2024, 0.09287210152394376),
#              (2025, 0.04974924189707863)])
# AutoOrderedDict([('len', 34),
#                  ('drawdown', 0.9157104494636922),
#                  ('moneydown', 1113.4846399999951),
#                  ('max',
#                   AutoOrderedDict([('len', 878),
#                                    ('drawdown', 12.20596892177149),
#                                    ('moneydown', 14292.126259999844)]))])
